# %% [markdown]
# ### MODEL 7: LASSO REGRESSION
# Predicting the model after using the L1 regularisation technique.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train = pd.read_csv('/home/ashly/Desktop/Machine Learning/Lab Assignment/Lab Assignment 9-10-20/DataSet1/train1.csv')
test = pd.read_csv('/home/ashly/Desktop/Machine Learning/Lab Assignment/Lab Assignment 9-10-20/DataSet1/test1.csv')

from sklearn.model_selection import train_test_split
X = train.drop('Item_Outlet_Sales',1)
x_train, x_cv, y_train, y_cv = train_test_split(X,train.Item_Outlet_Sales, test_size =0.3)

from sklearn.linear_model import Lasso
lassoReg = Lasso(alpha=0.3, normalize=True)
lassoReg.fit(x_train,y_train)
pred_cv = lassoReg.predict(x_cv)

# calculating mse
mse = np.mean((pred_cv - y_cv)**2)

print(mse)

lassoReg.score(x_cv,y_cv)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-0fbed94965b8> in <module>
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#       5
# ----> 6 train = pd.read_csv('/home/ashly/Desktop/Machine Learning/Lab Assignment/Lab Assignment 9-10-20/DataSet1/train1.csv')
#       7 test = pd.read_csv('/home/ashly/Desktop/Machine Learning/Lab Assignment/Lab Assignment 9-10-20/DataSet1/test1.csv')
#       8
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~/miniconda3/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/ashly/Desktop/Machine Learning/Lab Assignment/Lab Assignment 9-10-20/DataSet1/train1.csv'

# %% [raw]
# The following cases various values for alpha and thier corresponding coefficents are plotted

# %%
lassoReg = Lasso(alpha=0.3, normalize=True)
lassoReg.fit(x_train,y_train)
pred_cv = lassoReg.predict(x_cv)

#checking the magnitude of coefficients
predictors = x_train.columns

# Using pd.Series() to produce a one dimensional array to show the axis labels
# and .sort_values() to sort them in ascending order to see the labels which closely related to the target variable
coef = pd.Series(lassoReg.coef_,predictors).sort_values()
    

coef.plot(kind='bar', title='Modal Coefficients')

#calculating score 
lassoReg.score(x_cv,y_cv)
# Out:
# 0.6107394307529184

# %%
lassoReg = Lasso(alpha=3, normalize=True)
lassoReg.fit(x_train,y_train)
pred_cv = lassoReg.predict(x_cv)

#checking the magnitude of coefficients
predictors = x_train.columns

# Using pd.Series() to produce a one dimensional array to show the axis labels
# and .sort_values() to sort them in ascending order to see the labels which closely related to the target variable
coef = pd.Series(lassoReg.coef_,predictors).sort_values()
    

coef.plot(kind='bar', title='Modal Coefficients')

#calculating score 
lassoReg.score(x_cv,y_cv)
# Out:
# 0.5882708142333333
